# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/MyDrive/'Colab Notebooks'/RL_Python
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/RL_Python
# baby-steps-of-rl-ja  RL_Python.ipynb

# %%
# !python ./baby-steps-of-rl-ja/DP/environment.py
# !python ./baby-steps-of-rl-ja/DP/environment_demo.py

# %%
# !cat ./baby-steps-of-rl-ja/DP/bellman_equation.py

# %%
# !cat ./baby-steps-of-rl-ja/DP/planner.py

# %%
# !cat ./baby-steps-of-rl-ja/EL/epsilon_greedy.py

# %%
# !cat ./baby-steps-of-rl-ja/EL/monte_carlo.py

# %%
# !cat ./baby-steps-of-rl-ja/EL/q_learning.py

# %%
# !cat ./baby-steps-of-rl-ja/EL/actor_critic.py

# %%
# !ls ./baby-steps-of-rl-ja/EL
# Out:
# actor_critic.py  epsilon_greedy.py    monte_carlo.py  sarsa.py
# compare_q_s.py	 frozen_lake_util.py  notebooks
# el_agent.py	 __init__.py	      q_learning.py

# %%
# !python ./baby-steps-of-rl-ja/DP/bellman_equation.py
# Out:
# 0.7880942034605892
# 0.9068026334400001
# -0.96059601
